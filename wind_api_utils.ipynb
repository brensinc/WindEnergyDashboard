# %% [markdown]
# Set up requests from Open-Meteo API. <br>
# <br>
# Sample API Endpoint for latitude=52.52 and longitude=13.41<br>
# Selects 15 min interval data for wind_speed_80m, wind_direction_80m, wind_gusts_10m from dates 2025-12-01 to 2025-12-30<br>
# https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&minutely_15=wind_speed_80m,wind_direction_80m,wind_gusts_10m&start_date=2025-12-01&end_date=2025-12-30

# %% [markdown]
# Start with hourly instead of 15 minute data for a start. Allows faster loading, data is clearer, and more realistic for energy analytics.

# %%
import requests
import pandas as pd

def get_wind_data(lat, lon, date_start, date_end):
    """
    Fetch historical + forecast wind data from Open-Meteo.

    Parameters
    ----------
    lat : float
        Latitude
    lon : float
        Longitude
    date_start : str
        Start date in YYYY-MM-DD format
    date_end : str
        End date in YYYY-MM-DD format

    Returns
    -------
    pd.DataFrame
        DataFrame with timestamp, wind speed, wind direction, and data type
    """

    url = "https://api.open-meteo.com/v1/forecast"

    params = {
        "latitude": lat,
        "longitude": lon,
        # Hourly is usually better for dashboards than 15-min to start
        "hourly": [
            "wind_speed_80m",
            "wind_direction_80m"
        ],
        "wind_speed_unit": "ms",
        "start_date": date_start,
        "end_date": date_end,
        "timezone": "UTC"
    }

    response = requests.get(url, params=params)
    response.raise_for_status()  # fail fast if API errors

    data = response.json()

    # Parse into DataFrame
    df = pd.DataFrame({
        "timestamp": pd.to_datetime(data["hourly"]["time"], utc=True),
        "wind_speed_mps": data["hourly"]["wind_speed_80m"],
        "wind_direction_deg": data["hourly"]["wind_direction_80m"],
    })

    return df

# %%
from datetime import datetime, timezone

def add_data_type(df):
    now = datetime.now(timezone.utc)    
    df["data_type"] = df["timestamp"].apply(
        lambda t: "historical" if t <= now else "forecast"
    )
    return df

# %%
# Example
lat=52.52 
lon=13.41
date_start="2025-12-01"
date_end="2025-12-10"

df = get_wind_data(lat, lon, date_start, date_end)
df = add_data_type(df)

# %%
print(df["timestamp"].dt.tz)
print(type(df["timestamp"].iloc[0]))
# Out:
# UTC
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
import numpy as np

def wind_to_power(
    wind_speed_mps,
    cut_in=3.0,
    rated_speed=12.0,
    cut_out=25.0,
    rated_power_mw=3.0
):
    """
    Convert wind speed to power output using an idealized power curve.

    Parameters
    ----------
    wind_speed_mps : float or np.ndarray
        Wind speed in m/s
    cut_in : float
        Cut-in wind speed (m/s)
    rated_speed : float
        Rated wind speed (m/s)
    cut_out : float
        Cut-out wind speed (m/s)
    rated_power_mw : float
        Rated power (MW)

    Returns
    -------
    power_mw : float or np.ndarray
        Power output (MW)
    """

    ws = np.array(wind_speed_mps)

    power = np.zeros_like(ws, dtype=float)

    # Linear ramp region
    ramp_mask = (ws >= cut_in) & (ws < rated_speed)
    power[ramp_mask] = rated_power_mw * (
        (ws[ramp_mask] - cut_in) / (rated_speed - cut_in)
    )

    # Rated region
    rated_mask = (ws >= rated_speed) & (ws <= cut_out)
    power[rated_mask] = rated_power_mw

    # Outside operating range stays 0
    return power

# %%
def add_power_output(df, turbine_params):
    df = df.copy()
    df["power_mw"] = wind_to_power(
        df["wind_speed_mps"].values,
        cut_in=turbine_params["cut_in"],
        rated_speed=turbine_params["rated_speed"],
        cut_out=turbine_params["cut_out"],
        rated_power_mw=turbine_params["rated_power_mw"],
    )
    return df

# %%
# pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.52.2-py3-none-any.whl.metadata (9.8 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (5.29.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-22.0.0-cp310-cp310-macosx_12_0_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.27.1 (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /Users/brendansinclair/opt/anaconda3/envs/machine_learning/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 4.5 MB/s eta 0:00:00a 0:00:01m
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading pyarrow-22.0.0-cp310-cp310-macosx_12_0_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, smmap, pyarrow, narwhals, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 1.26.0
#     Uninstalling narwhals-1.26.0:
#       Successfully uninstalled narwhals-1.26.0
# Successfully installed altair-6.0.0 blinker-1.9.0 cachetools-6.2.4 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.14.0 pyarrow-22.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.52.2 tenacity-9.1.2
# Note: you may need to restart the kernel to use updated packages.
