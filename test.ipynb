# %%
import gridstatus
iso = gridstatus.Ercot()
df = iso.get_spp(date="today", market="DAY_AHEAD_HOURLY", location_type="Trading Hub")
print(df.head(), df.shape)
# Out:
# 2026-01-03 18:36:23 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12331&_1767494183
# 2026-01-03 18:36:23 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12331&_1767494183 with {}
# 2026-01-03 18:36:24 - DEBUG - Reading https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1178079877
# 2026-01-03 18:36:27 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1767494187
# 2026-01-03 18:36:27 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=10008&_1767494187 with {}
# 2026-01-03 18:36:28 - INFO - Fetching https://www.ercot.com/misdownload/servlets/mirDownload?doclookupId=1172152090
#                        Time            Interval Start  \
# 0 2026-01-03 00:00:00-06:00 2026-01-03 00:00:00-06:00
# 1 2026-01-03 00:00:00-06:00 2026-01-03 00:00:00-06:00
# ...

# %%
df = iso.get_spp(date="2025-12-03", market="DAY_AHEAD_HOURLY", location_type="Trading Hub")
# Out:
# 2026-01-03 18:42:41 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12331&_1767494561
# 2026-01-03 18:42:41 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=12331&_1767494561 with {}
# ---------------------------------------------------------------------------
# NoDataFoundException                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = iso.get_spp(date="2025-12-03", market="DAY_AHEAD_HOURLY", location_type="Trading Hub")
#
# File ~/opt/anaconda3/envs/wind_dashboard/lib/python3.12/site-packages/gridstatus/lmp_config.py:24, in lmp_config.__call__.<locals>.wrapper(*args, **kwargs)
#      22 if len(args) > 0 and isinstance(args[0], ISOBase):
#      23     bound_args = self._verify_bound_args(bound_args)
# ---> 24     return self._class_method_wrapper(func, bound_args)
#      25 else:
#      26     # This is a runtime check after method is called.
# ...
